# %% [markdown]
# # Jane Street Market Prediction (#6)
# ## Ensemble - Bagging
#
# Notebook Navigation<br>
# [All](https://www.kaggle.com/wendellavila/janestreet-index/) | [#1](https://www.kaggle.com/wendellavila/janestreet-model-selection/) | [#2.1](https://www.kaggle.com/wendellavila/janestreet-preprocessing-selection) | [#2.2](https://www.kaggle.com/wendellavila/janestreet-data-preprocessing) | [#3](https://www.kaggle.com/wendellavila/janestreet-regularization-selection) | [#4.1](https://www.kaggle.com/wendellavila/janestreet-hyperparameter-tuning) | [#4.2](https://www.kaggle.com/wendellavila/janestreet-hyperparameter-evaluation) | [#5.1](https://www.kaggle.com/wendellavila/janestreet-pca) | [#5.2](https://www.kaggle.com/wendellavila/janestreet-autoencoder) | [#5.3](https://www.kaggle.com/wendellavila/janestreet-dimensionality-reduction-evaluation) |[#6](https://www.kaggle.com/wendellavila/janestreet-ensemble)

# %% [markdown]
# ## Imports

# %%
#import janestreet
import os
import glob
import IPython

import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 150)
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.models import load_model
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
#data loaded from another notebook
#already preprocessed and downsized for faster loading
#https://www.kaggle.com/code/wendellavila/janestreet-data-preprocessing/
train_data = pd.read_pickle('../input/janestreet-data-preprocessing/train-mean-indicator.pkl')
val_data = pd.read_pickle('../input/janestreet-data-preprocessing/val-mean-indicator.pkl')
features = [col for col in train_data.columns if 'feature' in col]
resp_cols = [col for col in train_data.columns if 'resp' in col]

# %%
train_data.tail()
# Out:
#          date    weight    resp_1    resp_2    resp_3    resp_4      resp  \
# 2112171   449  0.000000  0.000119  0.000119  0.002081  0.003141  0.000895
# 2112172   449  0.000000  0.000126  0.000126  0.000881 -0.002131 -0.002645
# 2112173   449  0.000000  0.000196  0.000196 -0.001564 -0.006363 -0.004242
# 2112174   449  0.000000 -0.000004 -0.000004 -0.001841 -0.006153 -0.004051
# 2112175   449  1.071289 -0.000363 -0.000363 -0.001492  0.000698  0.001924
#
#          feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 2112171         -1  -1.244141  -0.621582   0.965820   1.478516   0.830566
# 2112172         -1  -0.759766   0.003555  -0.710938  -0.986816   0.446777
# 2112173          1   1.150391   1.765625   1.018555   1.146484  -0.797852
# 2112174          1  -2.107422  -1.484375  -0.128418  -0.164673  -0.517090
# 2112175         -1  -1.113281  -1.479492   1.538086   1.257812   1.329102
#
#          feature_6  feature_7  feature_8  feature_9  feature_10  feature_11  \
# 2112171   1.325195  -0.286865  -0.300293  -1.616211   -0.738281    0.210449
# 2112172   0.710449   0.251465   0.659180  -0.863281   -0.005409    0.387451
# 2112173  -0.912109  -0.665527  -0.830566   0.070129    0.395020   -0.707520
# 2112174  -0.990234  -0.143921   0.069885  -0.197998    1.302734   -0.059143
# 2112175   1.121094  -0.214966  -0.302246   0.072571   -0.201172    0.740723
#
#          feature_12  feature_13  feature_14  feature_15  feature_16  \
# 2112171    1.066406   -0.451172    0.047791   -1.174805   -1.286133
# 2112172    1.487305   -0.015266    0.602539   -0.566406   -0.053131
# 2112173   -1.249023    0.252441    0.454102    0.035980    0.441406
# 2112174    0.729980    0.084106    1.226562   -0.091797    1.642578
# 2112175    0.950684    0.492188    0.171143   -0.008560   -0.358887
#
#          feature_17  feature_18  feature_19  feature_20  feature_21  \
# 2112171    0.359131    1.323242    1.026367    4.539062    4.199219
# 2112172   -0.908691   -0.270508   -0.129272    1.299805    1.149414
# 2112173   -1.517578   -1.231445   -1.243164   -0.890137   -0.735840
# 2112174   -1.568359   -1.146484    0.221558    4.226562    3.912109
# 2112175   -0.243286   -0.080627    0.305176    4.234375    3.925781
#
#          feature_62  feature_63  feature_64  feature_65  feature_66  \
# 2112171   -1.602539   -1.746094    5.867188    1.551758    1.302734
# 2112172    6.433594    6.621094    5.921875    4.546875    3.875000
# 2112173    6.492188    6.675781    5.953125    6.183594    5.042969
# 2112174    1.488281    1.542969    5.953125    1.775391    1.499023
# 2112175   -1.284180   -1.355469    6.027344    1.771484    1.491211
#
#          feature_67  ...  feature_19_missing  feature_20_missing  \
# 2112171    8.335938  ...                 0.0                 0.0
# 2112172   -0.049896  ...                 0.0                 0.0
# 2112173   -0.108215  ...                 0.0                 0.0
# 2112174    4.953125  ...                 0.0                 0.0
# 2112175    7.671875  ...                 0.0                 0.0
#
#          feature_21_missing  feature_22_missing  feature_23_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_24_missing  feature_25_missing  feature_26_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_27_missing  feature_28_missing  feature_29_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_30_missing  feature_31_missing  feature_32_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_33_missing  feature_34_missing  feature_35_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_36_missing  feature_44_missing  feature_45_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_55_missing  feature_56_missing  feature_58_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_59_missing  feature_72_missing  feature_73_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_74_missing  feature_75_missing  feature_76_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_78_missing  feature_79_missing  feature_80_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_81_missing  feature_82_missing  feature_84_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_85_missing  feature_86_missing  feature_87_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_88_missing  feature_90_missing  feature_91_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_92_missing  feature_93_missing  feature_94_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_96_missing  feature_97_missing  feature_98_missing  \
# 2112171                 0.0                 0.0                 0.0
# 2112172                 0.0                 0.0                 0.0
# 2112173                 0.0                 0.0                 0.0
# 2112174                 0.0                 0.0                 0.0
# 2112175                 0.0                 0.0                 0.0
#
#          feature_99_missing  feature_100_missing  feature_102_missing  \
# 2112171                 0.0                  0.0                  0.0
# 2112172                 0.0                  0.0                  0.0
# 2112173                 0.0                  0.0                  0.0
# 2112174                 0.0                  0.0                  0.0
# 2112175                 0.0                  0.0                  0.0
#
#          feature_103_missing  feature_104_missing  feature_105_missing  \
# 2112171                  0.0                  0.0                  0.0
# 2112172                  0.0                  0.0                  0.0
# 2112173                  0.0                  0.0                  0.0
# 2112174                  0.0                  0.0                  0.0
# 2112175                  0.0                  0.0                  0.0
#
#          feature_106_missing  feature_108_missing  feature_109_missing  \
# 2112171                  0.0                  0.0                  0.0
# 2112172                  0.0                  0.0                  0.0
# 2112173                  0.0                  0.0                  0.0
# 2112174                  0.0                  0.0                  0.0
# 2112175                  0.0                  0.0                  0.0
#
#          feature_110_missing  feature_111_missing  feature_112_missing  \
# 2112171                  0.0                  0.0                  0.0
# 2112172                  0.0                  0.0                  0.0
# 2112173                  0.0                  0.0                  0.0
# 2112174                  0.0                  0.0                  0.0
# 2112175                  0.0                  0.0                  0.0
#
#          feature_114_missing  feature_115_missing  feature_116_missing  \
# 2112171                  0.0                  0.0                  0.0
# 2112172                  0.0                  0.0                  0.0
# 2112173                  0.0                  0.0                  0.0
# 2112174                  0.0                  0.0                  0.0
# 2112175                  0.0                  0.0                  0.0
#
#          feature_117_missing  feature_118_missing  feature_120_missing  \
# 2112171                  0.0                  0.0                  0.0
# 2112172                  0.0                  0.0                  0.0
# 2112173                  0.0                  0.0                  0.0
# 2112174                  0.0                  0.0                  0.0
# 2112175                  0.0                  0.0                  0.0
#
#          feature_121_missing  feature_122_missing  feature_123_missing  \
# 2112171                  0.0                  0.0                  0.0
# 2112172                  0.0                  0.0                  0.0
# 2112173                  0.0                  0.0                  0.0
# 2112174                  0.0                  0.0                  0.0
# 2112175                  0.0                  0.0                  0.0
#
#          feature_124_missing  feature_125_missing  feature_126_missing  \
# 2112171                  0.0                  0.0                  0.0
# 2112172                  0.0                  0.0                  0.0
# 2112173                  0.0                  0.0                  0.0
# 2112174                  0.0                  0.0                  0.0
# 2112175                  0.0                  0.0                  0.0
#
#          feature_127_missing  feature_128_missing  feature_129_missing  action
# 2112171                  0.0                  0.0                  0.0       1
# 2112172                  0.0                  0.0                  0.0       0
# 2112173                  0.0                  0.0                  0.0       0
# 2112174                  0.0                  0.0                  0.0       0
# 2112175                  0.0                  0.0                  0.0       1
#
# [5 rows x 226 columns]

# %%
val_data.head()
# Out:
#          date    weight    resp_1    resp_2    resp_3    resp_4      resp  \
# 2112176   450  0.097412 -0.000833 -0.000835  0.000108  0.000228 -0.000529
# 2112177   450  0.000000  0.020889  0.027298  0.022491  0.005302  0.016983
# 2112178   450  0.651855 -0.001053 -0.001618 -0.003260 -0.005676 -0.003983
# 2112179   450  0.000000  0.000168  0.001943 -0.001282 -0.022720 -0.013214
# 2112180   450  3.785156 -0.000995 -0.002895 -0.003132  0.000731 -0.000527
#
#          feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
#
# 2112176                 1.0                 0.0                 0.0
# 2112177                 1.0                 0.0                 0.0
# 2112178                 1.0                 0.0                 0.0
# 2112179                 1.0                 0.0                 0.0
# 2112180                 1.0                 0.0                 0.0
#
#          feature_96_missing  feature_97_missing  feature_98_missing  \
# 2112176                 1.0                 0.0                 1.0
# 2112177                 1.0                 0.0                 1.0
# 2112178                 1.0                 0.0                 1.0
# 2112179                 1.0                 0.0                 1.0
# 2112180                 1.0                 0.0                 1.0
#
#          feature_99_missing  feature_100_missing  feature_102_missing  \
# 2112176                 0.0                  0.0                  1.0
# 2112177                 0.0                  0.0                  1.0
# 2112178                 0.0                  0.0                  1.0
# 2112179                 0.0                  0.0                  1.0
# 2112180                 0.0                  0.0                  1.0
#
#          feature_103_missing  feature_104_missing  feature_105_missing  \
# 2112176                  0.0                  1.0                  0.0
# 2112177                  0.0                  1.0                  0.0
# 2112178                  0.0                  1.0                  0.0
# 2112179                  0.0                  1.0                  0.0
# 2112180                  0.0                  1.0                  0.0
#
#          feature_106_missing  feature_108_missing  feature_109_missing  \
# 2112176                  0.0                  1.0                  0.0
# 2112177                  0.0                  1.0                  0.0
# 2112178                  0.0                  1.0                  0.0
# 2112179                  0.0                  1.0                  0.0
# 2112180                  0.0                  1.0                  0.0
#
#          feature_110_missing  feature_111_missing  feature_112_missing  \
# 2112176                  1.0                  0.0                  0.0
# 2112177                  1.0                  0.0                  0.0
# 2112178                  1.0                  0.0                  0.0
# 2112179                  1.0                  0.0                  0.0
# 2112180                  1.0                  0.0                  0.0
#
#          feature_114_missing  feature_115_missing  feature_116_missing  \
# 2112176                  1.0                  0.0                  1.0
# 2112177                  1.0                  0.0                  1.0
# 2112178                  1.0                  0.0                  1.0
# 2112179                  1.0                  0.0                  1.0
# 2112180                  1.0                  0.0                  1.0
#
#          feature_117_missing  feature_118_missing  feature_120_missing  \
# 2112176                  0.0                  0.0                  1.0
# 2112177                  0.0                  0.0                  1.0
# 2112178                  0.0                  0.0                  1.0
# 2112179                  0.0                  0.0                  1.0
# 2112180                  0.0                  0.0                  1.0
#
#          feature_121_missing  feature_122_missing  feature_123_missing  \
# 2112176                  1.0                  0.0                  0.0
# 2112177                  1.0                  0.0                  0.0
# 2112178                  1.0                  0.0                  0.0
# 2112179                  1.0                  0.0                  0.0
# 2112180                  1.0                  0.0                  0.0
#
#          feature_124_missing  feature_125_missing  feature_126_missing  \
# 2112176                  0.0                  0.0                  0.0
# 2112177                  0.0                  0.0                  0.0
# 2112178                  0.0                  0.0                  0.0
# 2112179                  0.0                  0.0                  0.0
# 2112180                  0.0                  0.0                  0.0
#
#          feature_127_missing  feature_128_missing  feature_129_missing  action
# 2112176                  0.0                  0.0                  0.0       0
# 2112177                  0.0                  0.0                  0.0       1
# 2112178                  0.0                  0.0                  0.0       0
# 2112179                  0.0                  0.0                  0.0       0
# 2112180                  0.0                  0.0                  0.0       0
#
# [5 rows x 226 columns]

# %% [markdown]
# ## Visualization

# %%
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics, 'b')
    plt.plot(epochs, val_metrics, 'g')
    if metric == 'AUC':
        plt.axhline(y=0.5,ls=":",c="gray")
        plt.ylim(ymin=0.48)
    elif metric == 'MSE':
        plt.axhline(y=0.0,ls=":",c="gray")
        plt.ylim(ymin=-0.05, ymax=0.25)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %% [markdown]
# ## Misc

# %%
def set_seed(seed : int):    
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

# %%
# weighted average as per Donate et al.'s formula
# https://doi.org/10.1016/j.neucom.2012.02.053
def weighted_average(a):
    w = []
    n = len(a)
    for i in range(1, n + 1):
        i = 2 if i == 1 else i
        w.append(1 / (2**(n + 1 - i)))
    return np.average(a, weights = w)

# %%
class ClearTrainingOutput(tf.keras.callbacks.Callback):
      def on_train_end(*args, **kwargs):
        IPython.display.clear_output(wait = True)

# %%
class Hyperparameters:
  def __init__(self, topology, dropout_rates, learning_rate, activation, num_input,
               num_batch, num_epochs, label_smoothing, use_batchnorm, use_encoder):
    self.topology = topology
    self.dropout_rates = dropout_rates
    self.learning_rate = learning_rate
    self.activation = activation
    self.num_input = num_input
    self.num_batch = num_batch
    self.num_epochs = num_epochs
    self.label_smoothing = label_smoothing
    self.use_batchnorm = use_batchnorm
    self.use_encoder = use_encoder

# %% [markdown]
# ## Utility Score

# %%
def utility_score(d, w, r, a):
    Pi = np.bincount(d, w * r * a)
    t = np.sum(Pi) / np.sqrt(np.sum(Pi ** 2)) * np.sqrt(250 / len(Pi))
    u = min(max(t, 0), 6) * np.sum(Pi)
    return u

# %% [markdown]
# ## CV - Purged Group Time Series Split

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args

# modified code for group gaps; source
# https://github.com/getgaurav2/scikit-learn/blob/d4a3af5cc9da3a76f0266932644b884c99724c57/sklearn/model_selection/_split.py#L2243
class PurgedGroupTimeSeriesSplit(_BaseKFold):
    """Time Series cross-validator variant with non-overlapping groups.
    Allows for a gap in groups to avoid potentially leaking info from
    train into test if the model has windowed or lag features.
    Provides train/test indices to split time series data samples
    that are observed at fixed time intervals according to a
    third-party provided group.
    In each split, test indices must be higher than before, and thus shuffling
    in cross validator is inappropriate.
    This cross-validation object is a variation of :class:`KFold`.
    In the kth split, it returns first k folds as train set and the
    (k+1)th fold as test set.
    The same group will not appear in two different folds (the number of
    distinct groups has to be at least equal to the number of folds).
    Note that unlike standard cross-validation methods, successive
    training sets are supersets of those that come before them.
    Read more in the :ref:`User Guide <cross_validation>`.
    Parameters
    ----------
    n_splits : int, default=5
        Number of splits. Must be at least 2.
    max_train_group_size : int, default=Inf
        Maximum group size for a single training set.
    group_gap : int, default=None
        Gap between train and test
    max_test_group_size : int, default=Inf
        We discard this number of groups from the end of each train split
    """

    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_group_size=np.inf,
                 max_test_group_size=np.inf,
                 group_gap=None,
                 verbose=False
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_group_size = max_train_group_size
        self.group_gap = group_gap
        self.max_test_group_size = max_test_group_size
        self.verbose = verbose

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        group_gap = self.group_gap
        max_test_group_size = self.max_test_group_size
        max_train_group_size = self.max_train_group_size
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))

        group_test_size = min(n_groups // n_folds, max_test_group_size)
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []

            group_st = max(0, group_test_start - group_gap - max_train_group_size)
            for train_group_idx in unique_groups[group_st:(group_test_start - group_gap)]:
                train_array_tmp = group_dict[train_group_idx]
                
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)

            train_end = train_array.size
 
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)

            test_array  = test_array[group_gap:]
            
            
            if self.verbose > 0:
                    pass
                    
            yield [int(i) for i in train_array], [int(i) for i in test_array]

# %% [markdown]
# ## Building and Training Models

# %% [markdown]
# ### Defining model

# %%
def create_autoencoder(num_input,num_output,noise=0.05):
    i = layers.Input(num_input)
    encoded = layers.BatchNormalization()(i)
    encoded = layers.GaussianNoise(noise)(encoded)
    encoded = layers.Dense(64,activation='relu')(encoded)
    decoded = layers.Dropout(0.2)(encoded)
    decoded = layers.Dense(num_input,name='decoded')(decoded)
    x = layers.Dense(32,activation='relu')(decoded)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(num_output,activation='sigmoid',name='label_output')(x)
    
    encoder = tf.keras.models.Model(inputs=i,outputs=decoded)
    autoencoder = tf.keras.models.Model(inputs=i,outputs=[decoded,x])

    autoencoder.compile(optimizer=tf.keras.optimizers.Adam(0.001),
                        loss={'decoded':'mse','label_output':'binary_crossentropy'})
    return autoencoder, encoder

# %%
def create_model(topology, dropout_rates, num_input, num_output, lrate, activation,
                 label_smoothing, use_batchnorm, use_encoder):
    
    inp = layers.Input(shape = (num_input,), name='X_train')
    
    x = inp
    if use_encoder == True:
        autoencoder, encoder = create_autoencoder(num_input,num_output,noise=0.05)
        encoder.load_weights('../input/janestreet-autoencoder/encoder.h5')
        x = encoder(x)
    if use_batchnorm == True:
        x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout_rates[0])(x)
        
    for i in range(len(topology)): 
        x = layers.Dense(topology[i])(x)
        if use_batchnorm == True:
            x = layers.BatchNormalization()(x)
        x = layers.Activation(activation)(x)
        x = layers.Dropout(dropout_rates[i+1])(x)
    
    x = layers.Dense(num_output)(x)
    out = layers.Activation('sigmoid')(x)
    
    model = tf.keras.models.Model(inputs=inp, outputs=out)
    
    opt = tf.keras.optimizers.Adam(learning_rate = lrate)
    model.compile(optimizer = opt,
                  loss = tf.keras.losses.BinaryCrossentropy(label_smoothing = label_smoothing),
                  metrics = tf.keras.metrics.AUC(name='AUC'))
    
    return model

# %% [markdown]
# ### Defining Training

# %%
def train_model(name, hp, n_folds):
    
    print(f'{name}: Training...')
    cv = PurgedGroupTimeSeriesSplit(
        n_splits=n_folds,
        max_train_group_size=150,
        group_gap=20,
        max_test_group_size=60
    )
    
    for fold, (train_index, test_index) in enumerate(cv.split(train_data, groups=train_data['date'].values)):
        
        print(f'{name} - Fold {fold+1} of {n_folds}')
        train_set = train_data.iloc[train_index]
        test_set = train_data.iloc[test_index]
        
        X_train = train_set.loc[:, features].values
        X_test = test_set.loc[:, features].values
        
        y_train = np.stack([(train_set[col] > 0).astype('int') for col in resp_cols]).T #Multitarget
        y_test = np.stack([(test_set[col] > 0).astype('int') for col in resp_cols]).T #Multitarget
        model = create_model(hp.topology, hp.dropout_rates, hp.num_input, len(resp_cols), hp.learning_rate,
                             hp.activation, hp.label_smoothing, hp. use_batchnorm, hp.use_encoder)
        metric = 'AUC'
        metric_mode = 'max'
        
        early_stopping = EarlyStopping(monitor=f'val_{metric}',patience=15,min_delta=0.0001,mode=metric_mode,
                                       restore_best_weights=True)
        #rlr = ReduceLROnPlateau(monitor=f'val_{metric}', factor=0.1, patience=5, verbose=0, min_delta = 0.0001, mode=metric_mode)
        
        callbacks = [early_stopping, [ClearTrainingOutput()]]

        history = model.fit(X_train, y_train,
                            batch_size = hp.num_batch,
                            epochs = hp.num_epochs,
                            validation_data = (X_test, y_test),
                            callbacks=callbacks,
                            verbose=2)
        
        plot_metric(history, metric)
        model.save(f'./{name}-fold{str(fold+1)}-seed{str(SEED)}.h5')

# %% [markdown]
# ### Defining Utility Score Validation

# %%
# def validate_model(name, n_folds, n_seeds):
#     print(f'{name}: Validating...')
    
#     #validation data
#     X_val = val_data.loc[:, features].values
#     y_val = val_data.loc[:, 'action'].values 
    
#     scores = []
    
#     for SEED in range(n_seeds):
#         set_seed(SEED)
#         #loading pretrained models
#         models = []
#         for i in range(n_folds):
#             models.append(tf.keras.models.load_model(f'./{name}-fold{str(i+1)}-seed{str(SEED)}.h5'))
#         print(f'SEED {SEED} - All models loaded.')
    
#         curr_val_preds = []
#         for model in models:
#             curr_val_pred = model.predict(X_val)
#             curr_val_pred = np.array([np.mean(preds) for preds in curr_val_pred])
#             curr_val_preds.append(curr_val_pred)
#         curr_val_preds_avg = np.asarray([weighted_average(idx) for idx in zip(*curr_val_preds)])
#         curr_val_preds_avg = ((curr_val_preds_avg > 0.501)*1)
            
#         curr_uscore = utility_score(val_data['date'].values, val_data['weight'].values,
#                                         val_data['resp'].values, curr_val_preds_avg)
#         print(f'SEED {SEED} {name} {n_folds}-fold Utility Score: {curr_uscore}\n')
#         scores.append(curr_uscore)
        
#     print(f'Average {n_folds}-fold Utility Score: {np.mean(scores)}\n')

# %%
def validate_models_ensemble(names, n_folds, n_seeds):
    print('Ensemble: Validating...\n')
    
    #validation data
    X_val = val_data.loc[:, features].values
    y_val = val_data.loc[:, 'action'].values
    
    
    val_preds = []
    scores = []
    
    for SEED in range(n_seeds):
        print(f'SEED {SEED}: Validating...')
        seed_val_preds = []
        for name in names:
            set_seed(SEED)
            #loading pretrained models
            models = []
            for i in range(n_folds):
                models.append(tf.keras.models.load_model(f'./{name}-fold{str(i+1)}-seed{str(SEED)}.h5'))
            print(f'SEED {SEED} {name} - All models loaded.')

            curr_val_preds = []
            for model in models:
                curr_val_pred = model.predict(X_val)
                curr_val_pred = np.array([np.mean(preds) for preds in curr_val_pred])
                curr_val_preds.append(curr_val_pred)
            curr_val_preds_avg = np.asarray([weighted_average(idx) for idx in zip(*curr_val_preds)])
            val_preds.append(curr_val_preds_avg)
            seed_val_preds.append(curr_val_preds_avg)
            
        seed_val_preds_avg = np.asarray([np.mean(idx) for idx in zip(*seed_val_preds)])
        seed_val_preds_avg = ((seed_val_preds_avg > 0.501)*1)
        seed_uscore = utility_score(val_data['date'].values, val_data['weight'].values,
                                            val_data['resp'].values, seed_val_preds_avg)
        print(f'SEED {SEED} {len(names)}-model 5-fold Utility Score: {seed_uscore}\n')
        scores.append(seed_uscore)

    val_preds_avg = np.asarray([np.mean(idx) for idx in zip(*val_preds)])
    val_preds_avg = ((val_preds_avg > 0.501)*1)
    ensemble_uscore = utility_score(val_data['date'].values, val_data['weight'].values,
                                            val_data['resp'].values, val_preds_avg)
    
    print(f'SEED scores Average: {np.mean(scores)}')
    print(f'{n_seeds} SEEDS x {len(names)} Models x {n_folds} Fold Ensemble (Total {n_seeds * len(names) * n_folds} models): Utility Score: {ensemble_uscore}\n')

# %% [markdown]
# ### Training and validating

# %%
n_seeds = 5
n_folds = 5
num_batch = 4096
num_epochs = 150
num_input = len(features)

# %%
topology = [208, 48, 112, 848, 624]
dropout_rates = [0.15543385946124283,0.4769936942603337,0.2004355862256995,
                 0.4212563172737503,0.46071906728999595,0.43182424636157835]
learning_rate = 0.001
activation = 'swish'

label_smoothing = 0.47213403813669336
use_batchnorm = True
use_encoder = True
model1_hyperparameters = Hyperparameters(topology, dropout_rates, learning_rate,
                                  activation, num_input, num_batch, num_epochs,
                                  label_smoothing, use_batchnorm, use_encoder)

# %%
topology = [240,352,976,176,448]
dropout_rates = [0.13021918620948872,0.2612506117600616,0.43285170482208624,
                 0.42634106968809327,0.449529191355194,0.30937895483115463]
learning_rate = 0.001
activation = 'swish'

label_smoothing = 0.47457896527611876
use_batchnorm = True
use_encoder = True
model2_hyperparameters = Hyperparameters(topology, dropout_rates, learning_rate,
                                  activation, num_input, num_batch, num_epochs,
                                  label_smoothing, use_batchnorm, use_encoder)

# %%
topology = [416,504,256,568,368]
dropout_rates = [0.1747245172397526,0.46609158038970466,0.42073578763921193,
                 0.23349072903009116,0.413193305598212,0.4562599801134036]
learning_rate = 0.001
activation = 'swish'

label_smoothing = 0.39645093182491814
use_batchnorm = True
use_encoder = True
model3_hyperparameters = Hyperparameters(topology, dropout_rates, learning_rate,
                                  activation, num_input, num_batch, num_epochs,
                                  label_smoothing, use_batchnorm, use_encoder)

# %%
#training model
for SEED in range(n_seeds):
    set_seed(SEED)
    train_model('Model1', model1_hyperparameters, n_folds)

# %%
#training model
for SEED in range(n_seeds):
    set_seed(SEED)
    train_model('Model2', model2_hyperparameters, n_folds)

# %%
#training model
for SEED in range(n_seeds):
    set_seed(SEED)
    train_model('Model3', model3_hyperparameters, n_folds)

# %%
validate_models_ensemble(['Model1'], n_folds, n_seeds)
# Out:
# Ensemble: Validating...
#
# SEED 0: Validating...
# SEED 0 Model1 - All models loaded.
# SEED 0 1-model 5-fold Utility Score: 798.9094884894906
#
# SEED 1: Validating...
# SEED 1 Model1 - All models loaded.
# SEED 1 1-model 5-fold Utility Score: 944.1402155633461
#
# SEED 2: Validating...
# SEED 2 Model1 - All models loaded.
# SEED 2 1-model 5-fold Utility Score: 805.3486913049086
#
# SEED 3: Validating...
# SEED 3 Model1 - All models loaded.
# SEED 3 1-model 5-fold Utility Score: 851.9457126049226
#
# SEED 4: Validating...
# SEED 4 Model1 - All models loaded.
# SEED 4 1-model 5-fold Utility Score: 893.893687693111
#
# SEED scores Average: 858.8475591311559
# 5 SEEDS x 1 Models x 5 Fold Ensemble (Total 25 models): Utility Score: 856.8154014457946

# %%
validate_models_ensemble(['Model2'], n_folds, n_seeds)
# Out:
# Ensemble: Validating...
#
# SEED 0: Validating...
# SEED 0 Model2 - All models loaded.
# SEED 0 1-model 5-fold Utility Score: 981.6727929881409
#
# SEED 1: Validating...
# SEED 1 Model2 - All models loaded.
# SEED 1 1-model 5-fold Utility Score: 1006.6897795053286
#
# SEED 2: Validating...
# SEED 2 Model2 - All models loaded.
# SEED 2 1-model 5-fold Utility Score: 720.212460781769
#
# SEED 3: Validating...
# SEED 3 Model2 - All models loaded.
# SEED 3 1-model 5-fold Utility Score: 667.5287626037463
#
# SEED 4: Validating...
# SEED 4 Model2 - All models loaded.
# SEED 4 1-model 5-fold Utility Score: 895.1789522406388
#
# SEED scores Average: 854.2565496239247
# 5 SEEDS x 1 Models x 5 Fold Ensemble (Total 25 models): Utility Score: 879.3841889123593

# %%
validate_models_ensemble(['Model3'], n_folds, n_seeds)
# Out:
# Ensemble: Validating...
#
# SEED 0: Validating...
# SEED 0 Model3 - All models loaded.
# SEED 0 1-model 5-fold Utility Score: 878.570980199967
#
# SEED 1: Validating...
# SEED 1 Model3 - All models loaded.
# SEED 1 1-model 5-fold Utility Score: 807.7255955552691
#
# SEED 2: Validating...
# SEED 2 Model3 - All models loaded.
# SEED 2 1-model 5-fold Utility Score: 812.6969941154254
#
# SEED 3: Validating...
# SEED 3 Model3 - All models loaded.
# SEED 3 1-model 5-fold Utility Score: 809.023330655536
#
# SEED 4: Validating...
# SEED 4 Model3 - All models loaded.
# SEED 4 1-model 5-fold Utility Score: 670.0604256771497
#
# SEED scores Average: 795.6154652406694
# 5 SEEDS x 1 Models x 5 Fold Ensemble (Total 25 models): Utility Score: 790.9755087215033

# %%
validate_models_ensemble(['Model1', 'Model2'], n_folds, n_seeds)
# Out:
# Ensemble: Validating...
#
# SEED 0: Validating...
# SEED 0 Model1 - All models loaded.
# SEED 0 Model2 - All models loaded.
# SEED 0 2-model 5-fold Utility Score: 935.4887317118834
#
# SEED 1: Validating...
# SEED 1 Model1 - All models loaded.
# SEED 1 Model2 - All models loaded.
# SEED 1 2-model 5-fold Utility Score: 967.3908561802273
#
# SEED 2: Validating...
# SEED 2 Model1 - All models loaded.
# SEED 2 Model2 - All models loaded.
# SEED 2 2-model 5-fold Utility Score: 901.6169270361515
#
# SEED 3: Validating...
# SEED 3 Model1 - All models loaded.
# SEED 3 Model2 - All models loaded.
# SEED 3 2-model 5-fold Utility Score: 760.4148365345109
#
# SEED 4: Validating...
# SEED 4 Model1 - All models loaded.
# SEED 4 Model2 - All models loaded.
# SEED 4 2-model 5-fold Utility Score: 942.4764015315071
#
# SEED scores Average: 901.477550598856
# 5 SEEDS x 2 Models x 5 Fold Ensemble (Total 50 models): Utility Score: 896.8312680422695

# %%
validate_models_ensemble(['Model1', 'Model3'], n_folds, n_seeds)
# Out:
# Ensemble: Validating...
#
# SEED 0: Validating...
# SEED 0 Model1 - All models loaded.
# SEED 0 Model3 - All models loaded.
# SEED 0 2-model 5-fold Utility Score: 828.2896986816537
#
# SEED 1: Validating...
# SEED 1 Model1 - All models loaded.
# SEED 1 Model3 - All models loaded.
# SEED 1 2-model 5-fold Utility Score: 851.8375585395013
#
# SEED 2: Validating...
# SEED 2 Model1 - All models loaded.
# SEED 2 Model3 - All models loaded.
# SEED 2 2-model 5-fold Utility Score: 825.447277980851
#
# SEED 3: Validating...
# SEED 3 Model1 - All models loaded.
# SEED 3 Model3 - All models loaded.
# SEED 3 2-model 5-fold Utility Score: 871.8551998622431
#
# SEED 4: Validating...
# SEED 4 Model1 - All models loaded.
# SEED 4 Model3 - All models loaded.
# SEED 4 2-model 5-fold Utility Score: 802.1461418277952
#
# SEED scores Average: 835.9151753784088
# 5 SEEDS x 2 Models x 5 Fold Ensemble (Total 50 models): Utility Score: 827.9430078827919

# %%
validate_models_ensemble(['Model2', 'Model3'], n_folds, n_seeds)
# Out:
# Ensemble: Validating...
#
# SEED 0: Validating...
# SEED 0 Model2 - All models loaded.
# SEED 0 Model3 - All models loaded.
# SEED 0 2-model 5-fold Utility Score: 979.1557437689792
#
# SEED 1: Validating...
# SEED 1 Model2 - All models loaded.
# SEED 1 Model3 - All models loaded.
# SEED 1 2-model 5-fold Utility Score: 911.8296727987017
#
# SEED 2: Validating...
# SEED 2 Model2 - All models loaded.
# SEED 2 Model3 - All models loaded.
# SEED 2 2-model 5-fold Utility Score: 706.125590811856
#
# SEED 3: Validating...
# SEED 3 Model2 - All models loaded.
# SEED 3 Model3 - All models loaded.
# SEED 3 2-model 5-fold Utility Score: 709.3604839368143
#
# SEED 4: Validating...
# SEED 4 Model2 - All models loaded.
# SEED 4 Model3 - All models loaded.
# SEED 4 2-model 5-fold Utility Score: 813.5846208897012
#
# SEED scores Average: 824.0112224412105
# 5 SEEDS x 2 Models x 5 Fold Ensemble (Total 50 models): Utility Score: 855.4715807692072

# %%
validate_models_ensemble(['Model1','Model2', 'Model3'], n_folds, n_seeds)
# Out:
# Ensemble: Validating...
#
# SEED 0: Validating...
# SEED 0 Model1 - All models loaded.
# SEED 0 Model2 - All models loaded.
# SEED 0 Model3 - All models loaded.
# SEED 0 3-model 5-fold Utility Score: 883.0071122126501
#
# SEED 1: Validating...
# SEED 1 Model1 - All models loaded.
# SEED 1 Model2 - All models loaded.
# SEED 1 Model3 - All models loaded.
# SEED 1 3-model 5-fold Utility Score: 902.7807779863917
#
# SEED 2: Validating...
# SEED 2 Model1 - All models loaded.
# SEED 2 Model2 - All models loaded.
# SEED 2 Model3 - All models loaded.
# SEED 2 3-model 5-fold Utility Score: 787.3821816117941
#
# SEED 3: Validating...
# SEED 3 Model1 - All models loaded.
# SEED 3 Model2 - All models loaded.
# SEED 3 Model3 - All models loaded.
# SEED 3 3-model 5-fold Utility Score: 748.5955868045047
#
# SEED 4: Validating...
# SEED 4 Model1 - All models loaded.
# SEED 4 Model2 - All models loaded.
# SEED 4 Model3 - All models loaded.
# SEED 4 3-model 5-fold Utility Score: 876.4227938840686
#
# SEED scores Average: 839.6376904998818
# 5 SEEDS x 3 Models x 5 Fold Ensemble (Total 75 models): Utility Score: 858.661831183327
